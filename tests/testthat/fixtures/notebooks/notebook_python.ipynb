# %% [markdown]
# # Analysis
# Prose, not code.

# %%
# %matplotlib inline
# !pip install pandas
import pandas as pd
import numpy as np
from scipy import stats  # comment
df = pd.read_csv('data/trials.csv')

# %%
df.groupby('cond').agg(['mean'])
# Out:
# <table border="1"><thead><tr><th>cond</th><th>t</th><th>df</th><th>p</th></tr></thead><tbody><tr><td>massed</td><td>3.41</td><td>48</td><td>0.001</td></tr><tr><td>spaced</td><td>2.07</td><td>48</td><td>0.044</td></tr></tbody></table>

# %%
print(stats.ttest_rel(a, b))
# Out:
# TtestResult(statistic=4.8977, pvalue=0.00007, df=22)

# %%
plt.plot(x, y)

# %%
x = 1  # never run
